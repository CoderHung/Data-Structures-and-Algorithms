# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from collections import deque

def bfs(graph, start):
    visited = set()
    queue = deque([start])
    order = []

    while queue:
        node = queue.popleft()
        if node not in visited:
            visited.add(node)
            order.append(node)
            for neighbor in graph.get(node, []):
                if neighbor not in visited:
                    queue.append(neighbor)

    return order

def dfs(graph, start):
    visited = set()
    stack = [start]
    order = []

    while stack:
        node = stack.pop()
        if node not in visited:
            visited.add(node)
            order.append(node)
            # Push neighbors in reverse to match left-to-right order
            for neighbor in reversed(graph.get(node, [])):
                if neighbor not in visited:
                    stack.append(neighbor)

    return order

# %%
def test_graph_traversal(traverse_func):
    graph1 = {
        'A': ['B', 'C'],
        'B': ['D', 'E'],
        'C': ['F'],
        'D': [],
        'E': [],
        'F': []
    }

    graph2 = {
        1: [2, 3],
        2: [4],
        3: [],
        4: [5],
        5: []
    }

    graph3 = {
        'X': ['Y'],
        'Y': ['Z'],
        'Z': ['X']  # cycle
    }

    print("Test 1:", traverse_func(graph1, 'A'))
    print("Test 2:", traverse_func(graph2, 1))
    print("Test 3:", traverse_func(graph3, 'X'))
    print("Test 4:", traverse_func({}, 'A'))
    print("Test 5:", traverse_func({'A': []}, 'A'))

# %%
test_graph_traversal(bfs)
print()
test_graph_traversal(dfs)
# Out:
# Test 1: ['A', 'B', 'C', 'D', 'E', 'F']
# Test 2: [1, 2, 3, 4, 5]
# Test 3: ['X', 'Y', 'Z']
# Test 4: ['A']
# Test 5: ['A']
#
# Test 1: ['A', 'B', 'D', 'E', 'C', 'F']
# Test 2: [1, 2, 4, 5, 3]
# Test 3: ['X', 'Y', 'Z']
# Test 4: ['A']
# Test 5: ['A']
